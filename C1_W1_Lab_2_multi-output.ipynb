# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 917us/sample - loss: 254.0980 - y1_output_loss: 121.0434 - y2_output_loss: 130.8637 - y1_output_root_mean_squared_error: 11.0510 - y2_output_root_mean_squared_error: 11.4880 - val_loss: 37.9304 - val_y1_output_loss: 15.7818 - val_y2_output_loss: 21.6705 - val_y1_output_root_mean_squared_error: 3.9476 - val_y2_output_root_mean_squared_error: 4.7273
# Epoch 2/500
# 614/614 [==============================] - 0s 146us/sample - loss: 30.5976 - y1_output_loss: 12.8505 - y2_output_loss: 17.6334 - y1_output_root_mean_squared_error: 3.5963 - y2_output_root_mean_squared_error: 4.2029 - val_loss: 28.6908 - val_y1_output_loss: 10.8235 - val_y2_output_loss: 17.2798 - val_y1_output_root_mean_squared_error: 3.2968 - val_y2_output_root_mean_squared_error: 4.2216
# Epoch 3/500
# 614/614 [==============================] - 0s 146us/sample - loss: 23.9261 - y1_output_loss: 9.7878 - y2_output_loss: 13.9162 - y1_output_root_mean_squared_error: 3.1433 - y2_output_root_mean_squared_error: 3.7478 - val_loss: 27.4944 - val_y1_output_loss: 10.5583 - val_y2_output_loss: 16.5538 - val_y1_output_root_mean_squared_error: 3.2240 - val_y2_output_root_mean_squared_error: 4.1353
# Epoch 4/500
# 614/614 [==============================] - 0s 136us/sample - loss: 30.2088 - y1_output_loss: 10.7496 - y2_output_loss: 19.4924 - y1_output_root_mean_squared_error: 3.2749 - y2_output_root_mean_squared_error: 4.4140 - val_loss: 34.9451 - val_y1_output_loss: 10.4123 - val_y2_output_loss: 23.9021 - val_y1_output_root_mean_squared_error: 3.2150 - val_y2_output_root_mean_squared_error: 4.9607
# Epoch 5/500
# 614/614 [==============================] - 0s 137us/sample - loss: 22.1918 - y1_output_loss: 8.7248 - y2_output_loss: 13.5706 - y1_output_root_mean_squared_error: 2.9523 - y2_output_root_mean_squared_error: 3.6710 - val_loss: 45.1867 - val_y1_output_loss: 13.6965 - val_y2_output_loss: 31.6982 - val_y1_output_root_mean_squared_error: 3.6191 - val_y2_output_root_mean_squared_error: 5.6647
# Epoch 6/500
# 614/614 [==============================] - 0s 137us/sample - loss: 19.8359 - y1_output_loss: 8.6992 - y2_output_loss: 11.1152 - y1_output_root_mean_squared_error: 2.9501 - y2_output_root_mean_squared_error: 3.3366 - val_loss: 26.1854 - val_y1_output_loss: 10.5774 - val_y2_output_loss: 15.1703 - val_y1_output_root_mean_squared_error: 3.2498 - val_y2_output_root_mean_squared_error: 3.9527
# Epoch 7/500
# 614/614 [==============================] - 0s 134us/sample - loss: 23.3507 - y1_output_loss: 9.2656 - y2_output_loss: 13.9479 - y1_output_root_mean_squared_error: 3.0553 - y2_output_root_mean_squared_error: 3.7438 - val_loss: 23.3203 - val_y1_output_loss: 8.1677 - val_y2_output_loss: 15.2221 - val_y1_output_root_mean_squared_error: 2.8678 - val_y2_output_root_mean_squared_error: 3.8853
# Epoch 8/500
# 614/614 [==============================] - 0s 133us/sample - loss: 24.9908 - y1_output_loss: 9.3387 - y2_output_loss: 15.4471 - y1_output_root_mean_squared_error: 3.0704 - y2_output_root_mean_squared_error: 3.9451 - val_loss: 20.2684 - val_y1_output_loss: 7.9411 - val_y2_output_loss: 12.0051 - val_y1_output_root_mean_squared_error: 2.8225 - val_y2_output_root_mean_squared_error: 3.5074
# Epoch 9/500
# 614/614 [==============================] - 0s 131us/sample - loss: 19.6578 - y1_output_loss: 8.1741 - y2_output_loss: 11.3475 - y1_output_root_mean_squared_error: 2.8685 - y2_output_root_mean_squared_error: 3.3807 - val_loss: 21.4717 - val_y1_output_loss: 7.8360 - val_y2_output_loss: 13.1734 - val_y1_output_root_mean_squared_error: 2.8073 - val_y2_output_root_mean_squared_error: 3.6866
# Epoch 10/500
# 614/614 [==============================] - 0s 136us/sample - loss: 20.4057 - y1_output_loss: 8.2521 - y2_output_loss: 12.0814 - y1_output_root_mean_squared_error: 2.8748 - y2_output_root_mean_squared_error: 3.4844 - val_loss: 24.3859 - val_y1_output_loss: 10.2371 - val_y2_output_loss: 13.8816 - val_y1_output_root_mean_squared_error: 3.1714 - val_y2_output_root_mean_squared_error: 3.7852
# Epoch 11/500
# 614/614 [==============================] - 0s 130us/sample - loss: 22.7702 - y1_output_loss: 8.7202 - y2_output_loss: 13.8922 - y1_output_root_mean_squared_error: 2.9638 - y2_output_root_mean_squared_error: 3.7398 - val_loss: 26.0105 - val_y1_output_loss: 7.9860 - val_y2_output_loss: 18.2827 - val_y1_output_root_mean_squared_error: 2.8373 - val_y2_output_root_mean_squared_error: 4.2380
# Epoch 12/500
# 614/614 [==============================] - 0s 132us/sample - loss: 20.0051 - y1_output_loss: 8.1595 - y2_output_loss: 11.9932 - y1_output_root_mean_squared_error: 2.8359 - y2_output_root_mean_squared_error: 3.4587 - val_loss: 46.5851 - val_y1_output_loss: 12.3281 - val_y2_output_loss: 33.5973 - val_y1_output_root_mean_squared_error: 3.4883 - val_y2_output_root_mean_squared_error: 5.8666
# Epoch 13/500
# 614/614 [==============================] - 0s 132us/sample - loss: 18.0473 - y1_output_loss: 7.6787 - y2_output_loss: 10.4183 - y1_output_root_mean_squared_error: 2.7691 - y2_output_root_mean_squared_error: 3.2217 - val_loss: 22.3937 - val_y1_output_loss: 7.5683 - val_y2_output_loss: 14.1939 - val_y1_output_root_mean_squared_error: 2.7767 - val_y2_output_root_mean_squared_error: 3.8319
# Epoch 14/500
# 614/614 [==============================] - 0s 134us/sample - loss: 20.4150 - y1_output_loss: 7.8118 - y2_output_loss: 12.5494 - y1_output_root_mean_squared_error: 2.8035 - y2_output_root_mean_squared_error: 3.5433 - val_loss: 20.3770 - val_y1_output_loss: 6.8010 - val_y2_output_loss: 13.5706 - val_y1_output_root_mean_squared_error: 2.6280 - val_y2_output_root_mean_squared_error: 3.6702
# Epoch 15/500
# 614/614 [==============================] - 0s 131us/sample - loss: 18.7616 - y1_output_loss: 7.2016 - y2_output_loss: 11.4526 - y1_output_root_mean_squared_error: 2.6965 - y2_output_root_mean_squared_error: 3.3898 - val_loss: 25.9398 - val_y1_output_loss: 7.8140 - val_y2_output_loss: 17.5887 - val_y1_output_root_mean_squared_error: 2.7837 - val_y2_output_root_mean_squared_error: 4.2651
# Epoch 16/500
# 614/614 [==============================] - 0s 132us/sample - loss: 17.2542 - y1_output_loss: 6.8109 - y2_output_loss: 10.4807 - y1_output_root_mean_squared_error: 2.5934 - y2_output_root_mean_squared_error: 3.2447 - val_loss: 24.6913 - val_y1_output_loss: 8.6407 - val_y2_output_loss: 15.7925 - val_y1_output_root_mean_squared_error: 2.9805 - val_y2_output_root_mean_squared_error: 3.9759
# Epoch 17/500
# 614/614 [==============================] - 0s 128us/sample - loss: 16.7051 - y1_output_loss: 6.7647 - y2_output_loss: 9.8110 - y1_output_root_mean_squared_error: 2.6087 - y2_output_root_mean_squared_error: 3.1464 - val_loss: 18.3905 - val_y1_output_loss: 6.1736 - val_y2_output_loss: 11.8127 - val_y1_output_root_mean_squared_error: 2.4788 - val_y2_output_root_mean_squared_error: 3.4994
# Epoch 18/500
# 614/614 [==============================] - 0s 131us/sample - loss: 15.0113 - y1_output_loss: 6.3730 - y2_output_loss: 8.5901 - y1_output_root_mean_squared_error: 2.5314 - y2_output_root_mean_squared_error: 2.9331 - val_loss: 27.4841 - val_y1_output_loss: 8.1820 - val_y2_output_loss: 19.1478 - val_y1_output_root_mean_squared_error: 2.9048 - val_y2_output_root_mean_squared_error: 4.3642
# Epoch 19/500
# 614/614 [==============================] - 0s 130us/sample - loss: 18.2939 - y1_output_loss: 6.8310 - y2_output_loss: 11.3130 - y1_output_root_mean_squared_error: 2.6255 - y2_output_root_mean_squared_error: 3.3765 - val_loss: 15.3894 - val_y1_output_loss: 5.7317 - val_y2_output_loss: 9.3946 - val_y1_output_root_mean_squared_error: 2.3805 - val_y2_output_root_mean_squared_error: 3.1181
# Epoch 20/500
# 614/614 [==============================] - 0s 129us/sample - loss: 14.9673 - y1_output_loss: 5.8639 - y2_output_loss: 9.4097 - y1_output_root_mean_squared_error: 2.4195 - y2_output_root_mean_squared_error: 3.0188 - val_loss: 34.2899 - val_y1_output_loss: 7.4540 - val_y2_output_loss: 27.8666 - val_y1_output_root_mean_squared_error: 2.7509 - val_y2_output_root_mean_squared_error: 5.1694
# Epoch 21/500
# 614/614 [==============================] - 0s 130us/sample - loss: 14.7619 - y1_output_loss: 5.9128 - y2_output_loss: 8.8964 - y1_output_root_mean_squared_error: 2.4204 - y2_output_root_mean_squared_error: 2.9839 - val_loss: 20.2037 - val_y1_output_loss: 5.8777 - val_y2_output_loss: 13.9123 - val_y1_output_root_mean_squared_error: 2.4148 - val_y2_output_root_mean_squared_error: 3.7911
# Epoch 22/500
# 614/614 [==============================] - 0s 128us/sample - loss: 13.5381 - y1_output_loss: 5.5271 - y2_output_loss: 7.9722 - y1_output_root_mean_squared_error: 2.3485 - y2_output_root_mean_squared_error: 2.8324 - val_loss: 18.9801 - val_y1_output_loss: 6.2778 - val_y2_output_loss: 12.5085 - val_y1_output_root_mean_squared_error: 2.4619 - val_y2_output_root_mean_squared_error: 3.5943
# Epoch 23/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.7089 - y1_output_loss: 5.4069 - y2_output_loss: 7.2373 - y1_output_root_mean_squared_error: 2.3338 - y2_output_root_mean_squared_error: 2.6948 - val_loss: 20.3309 - val_y1_output_loss: 6.0883 - val_y2_output_loss: 13.8942 - val_y1_output_root_mean_squared_error: 2.4419 - val_y2_output_root_mean_squared_error: 3.7905
# Epoch 24/500
# 614/614 [==============================] - 0s 127us/sample - loss: 14.1463 - y1_output_loss: 5.5938 - y2_output_loss: 8.4614 - y1_output_root_mean_squared_error: 2.3760 - y2_output_root_mean_squared_error: 2.9156 - val_loss: 16.5785 - val_y1_output_loss: 4.9981 - val_y2_output_loss: 11.5996 - val_y1_output_root_mean_squared_error: 2.2701 - val_y2_output_root_mean_squared_error: 3.3801
# Epoch 25/500
# 614/614 [==============================] - 0s 130us/sample - loss: 13.3310 - y1_output_loss: 5.3747 - y2_output_loss: 8.0476 - y1_output_root_mean_squared_error: 2.3071 - y2_output_root_mean_squared_error: 2.8299 - val_loss: 18.2092 - val_y1_output_loss: 7.1906 - val_y2_output_loss: 10.6575 - val_y1_output_root_mean_squared_error: 2.7282 - val_y2_output_root_mean_squared_error: 3.2812
# Epoch 26/500
# 614/614 [==============================] - 0s 133us/sample - loss: 12.2138 - y1_output_loss: 4.9841 - y2_output_loss: 7.6547 - y1_output_root_mean_squared_error: 2.2057 - y2_output_root_mean_squared_error: 2.7108 - val_loss: 40.6526 - val_y1_output_loss: 10.9574 - val_y2_output_loss: 29.6025 - val_y1_output_root_mean_squared_error: 3.2454 - val_y2_output_root_mean_squared_error: 5.4882
# Epoch 27/500
# 614/614 [==============================] - 0s 129us/sample - loss: 11.9615 - y1_output_loss: 4.7773 - y2_output_loss: 7.2270 - y1_output_root_mean_squared_error: 2.1879 - y2_output_root_mean_squared_error: 2.6785 - val_loss: 34.4377 - val_y1_output_loss: 8.3777 - val_y2_output_loss: 25.9210 - val_y1_output_root_mean_squared_error: 2.9491 - val_y2_output_root_mean_squared_error: 5.0735
# Epoch 28/500
# 614/614 [==============================] - 0s 133us/sample - loss: 12.4058 - y1_output_loss: 4.8750 - y2_output_loss: 7.4623 - y1_output_root_mean_squared_error: 2.2086 - y2_output_root_mean_squared_error: 2.7437 - val_loss: 11.1040 - val_y1_output_loss: 3.9343 - val_y2_output_loss: 6.9059 - val_y1_output_root_mean_squared_error: 1.9991 - val_y2_output_root_mean_squared_error: 2.6660
# Epoch 29/500
# 614/614 [==============================] - 0s 133us/sample - loss: 12.1485 - y1_output_loss: 4.4731 - y2_output_loss: 7.7274 - y1_output_root_mean_squared_error: 2.1075 - y2_output_root_mean_squared_error: 2.7761 - val_loss: 19.2063 - val_y1_output_loss: 6.6218 - val_y2_output_loss: 12.5666 - val_y1_output_root_mean_squared_error: 2.5085 - val_y2_output_root_mean_squared_error: 3.5936
# Epoch 30/500
# 614/614 [==============================] - 0s 133us/sample - loss: 11.2922 - y1_output_loss: 4.3545 - y2_output_loss: 6.8800 - y1_output_root_mean_squared_error: 2.0872 - y2_output_root_mean_squared_error: 2.6336 - val_loss: 11.6423 - val_y1_output_loss: 4.3208 - val_y2_output_loss: 7.0130 - val_y1_output_root_mean_squared_error: 2.0988 - val_y2_output_root_mean_squared_error: 2.6902
# Epoch 31/500
# 614/614 [==============================] - 0s 141us/sample - loss: 12.0796 - y1_output_loss: 4.2649 - y2_output_loss: 7.8080 - y1_output_root_mean_squared_error: 2.0644 - y2_output_root_mean_squared_error: 2.7960 - val_loss: 15.0194 - val_y1_output_loss: 4.9697 - val_y2_output_loss: 9.9858 - val_y1_output_root_mean_squared_error: 2.2675 - val_y2_output_root_mean_squared_error: 3.1429
# Epoch 32/500
# 614/614 [==============================] - 0s 132us/sample - loss: 11.8125 - y1_output_loss: 4.3995 - y2_output_loss: 7.3075 - y1_output_root_mean_squared_error: 2.1072 - y2_output_root_mean_squared_error: 2.7152 - val_loss: 10.5090 - val_y1_output_loss: 3.2860 - val_y2_output_loss: 7.0793 - val_y1_output_root_mean_squared_error: 1.8401 - val_y2_output_root_mean_squared_error: 2.6689
# Epoch 33/500
# 614/614 [==============================] - 0s 136us/sample - loss: 9.6314 - y1_output_loss: 3.6043 - y2_output_loss: 6.0135 - y1_output_root_mean_squared_error: 1.8982 - y2_output_root_mean_squared_error: 2.4552 - val_loss: 15.9266 - val_y1_output_loss: 4.9624 - val_y2_output_loss: 10.8545 - val_y1_output_root_mean_squared_error: 2.1793 - val_y2_output_root_mean_squared_error: 3.3432
# Epoch 34/500
# 614/614 [==============================] - 0s 139us/sample - loss: 9.1109 - y1_output_loss: 3.6278 - y2_output_loss: 5.4244 - y1_output_root_mean_squared_error: 1.9098 - y2_output_root_mean_squared_error: 2.3374 - val_loss: 12.4918 - val_y1_output_loss: 3.3333 - val_y2_output_loss: 9.1911 - val_y1_output_root_mean_squared_error: 1.8464 - val_y2_output_root_mean_squared_error: 3.0137
# Epoch 35/500
# 614/614 [==============================] - 0s 134us/sample - loss: 9.2185 - y1_output_loss: 3.5975 - y2_output_loss: 5.5738 - y1_output_root_mean_squared_error: 1.9055 - y2_output_root_mean_squared_error: 2.3638 - val_loss: 15.1878 - val_y1_output_loss: 4.2147 - val_y2_output_loss: 11.1016 - val_y1_output_root_mean_squared_error: 2.0637 - val_y2_output_root_mean_squared_error: 3.3059
# Epoch 36/500
# 614/614 [==============================] - 0s 136us/sample - loss: 9.8097 - y1_output_loss: 3.5292 - y2_output_loss: 6.2056 - y1_output_root_mean_squared_error: 1.8827 - y2_output_root_mean_squared_error: 2.5030 - val_loss: 10.1623 - val_y1_output_loss: 3.2633 - val_y2_output_loss: 6.7863 - val_y1_output_root_mean_squared_error: 1.8258 - val_y2_output_root_mean_squared_error: 2.6132
# Epoch 37/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.1583 - y1_output_loss: 3.7957 - y2_output_loss: 6.5641 - y1_output_root_mean_squared_error: 1.9475 - y2_output_root_mean_squared_error: 2.5230 - val_loss: 117.3136 - val_y1_output_loss: 17.7003 - val_y2_output_loss: 102.4641 - val_y1_output_root_mean_squared_error: 4.2371 - val_y2_output_root_mean_squared_error: 9.9680
# Epoch 38/500
# 614/614 [==============================] - 0s 140us/sample - loss: 9.5564 - y1_output_loss: 3.5059 - y2_output_loss: 6.0588 - y1_output_root_mean_squared_error: 1.8736 - y2_output_root_mean_squared_error: 2.4589 - val_loss: 13.4699 - val_y1_output_loss: 3.4876 - val_y2_output_loss: 10.3145 - val_y1_output_root_mean_squared_error: 1.8973 - val_y2_output_root_mean_squared_error: 3.1417
# Epoch 39/500
# 614/614 [==============================] - 0s 140us/sample - loss: 13.5992 - y1_output_loss: 3.9063 - y2_output_loss: 9.9252 - y1_output_root_mean_squared_error: 1.9725 - y2_output_root_mean_squared_error: 3.1158 - val_loss: 49.2620 - val_y1_output_loss: 12.0967 - val_y2_output_loss: 37.9199 - val_y1_output_root_mean_squared_error: 3.5220 - val_y2_output_root_mean_squared_error: 6.0710
# Epoch 40/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.6185 - y1_output_loss: 2.9568 - y2_output_loss: 5.6264 - y1_output_root_mean_squared_error: 1.7251 - y2_output_root_mean_squared_error: 2.3754 - val_loss: 8.7396 - val_y1_output_loss: 2.9921 - val_y2_output_loss: 5.7662 - val_y1_output_root_mean_squared_error: 1.6762 - val_y2_output_root_mean_squared_error: 2.4351
# Epoch 41/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.2785 - y1_output_loss: 2.7785 - y2_output_loss: 5.4373 - y1_output_root_mean_squared_error: 1.6730 - y2_output_root_mean_squared_error: 2.3409 - val_loss: 7.4137 - val_y1_output_loss: 1.9670 - val_y2_output_loss: 5.4346 - val_y1_output_root_mean_squared_error: 1.4120 - val_y2_output_root_mean_squared_error: 2.3281
# Epoch 42/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.6828 - y1_output_loss: 2.6849 - y2_output_loss: 4.9400 - y1_output_root_mean_squared_error: 1.6427 - y2_output_root_mean_squared_error: 2.2325 - val_loss: 7.5940 - val_y1_output_loss: 2.2540 - val_y2_output_loss: 5.3175 - val_y1_output_root_mean_squared_error: 1.5175 - val_y2_output_root_mean_squared_error: 2.3003
# Epoch 43/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.3044 - y1_output_loss: 2.4493 - y2_output_loss: 4.8274 - y1_output_root_mean_squared_error: 1.5639 - y2_output_root_mean_squared_error: 2.2042 - val_loss: 7.7698 - val_y1_output_loss: 2.2886 - val_y2_output_loss: 5.4661 - val_y1_output_root_mean_squared_error: 1.4895 - val_y2_output_root_mean_squared_error: 2.3561
# Epoch 44/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.8954 - y1_output_loss: 2.3200 - y2_output_loss: 4.7990 - y1_output_root_mean_squared_error: 1.5169 - y2_output_root_mean_squared_error: 2.1434 - val_loss: 17.6588 - val_y1_output_loss: 3.8417 - val_y2_output_loss: 13.6115 - val_y1_output_root_mean_squared_error: 1.9218 - val_y2_output_root_mean_squared_error: 3.7371
# Epoch 45/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.6731 - y1_output_loss: 2.6447 - y2_output_loss: 5.0184 - y1_output_root_mean_squared_error: 1.6306 - y2_output_root_mean_squared_error: 2.2393 - val_loss: 11.3837 - val_y1_output_loss: 2.8658 - val_y2_output_loss: 8.7123 - val_y1_output_root_mean_squared_error: 1.7242 - val_y2_output_root_mean_squared_error: 2.9001
# Epoch 46/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.9037 - y1_output_loss: 2.7865 - y2_output_loss: 6.1061 - y1_output_root_mean_squared_error: 1.6670 - y2_output_root_mean_squared_error: 2.4748 - val_loss: 11.1793 - val_y1_output_loss: 2.8071 - val_y2_output_loss: 8.2472 - val_y1_output_root_mean_squared_error: 1.6374 - val_y2_output_root_mean_squared_error: 2.9152
# Epoch 47/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.9637 - y1_output_loss: 2.3064 - y2_output_loss: 4.6538 - y1_output_root_mean_squared_error: 1.5128 - y2_output_root_mean_squared_error: 2.1622 - val_loss: 17.3323 - val_y1_output_loss: 5.5884 - val_y2_output_loss: 11.7536 - val_y1_output_root_mean_squared_error: 2.4042 - val_y2_output_root_mean_squared_error: 3.3989
# Epoch 48/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.7108 - y1_output_loss: 2.4013 - y2_output_loss: 5.2679 - y1_output_root_mean_squared_error: 1.5476 - y2_output_root_mean_squared_error: 2.3056 - val_loss: 7.7398 - val_y1_output_loss: 2.2391 - val_y2_output_loss: 5.4864 - val_y1_output_root_mean_squared_error: 1.4674 - val_y2_output_root_mean_squared_error: 2.3636
# Epoch 49/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.2430 - y1_output_loss: 2.3183 - y2_output_loss: 4.9463 - y1_output_root_mean_squared_error: 1.5147 - y2_output_root_mean_squared_error: 2.2246 - val_loss: 11.1037 - val_y1_output_loss: 2.3810 - val_y2_output_loss: 8.6100 - val_y1_output_root_mean_squared_error: 1.5001 - val_y2_output_root_mean_squared_error: 2.9755
# Epoch 50/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.5992 - y1_output_loss: 2.0996 - y2_output_loss: 4.4852 - y1_output_root_mean_squared_error: 1.4550 - y2_output_root_mean_squared_error: 2.1171 - val_loss: 10.3149 - val_y1_output_loss: 2.0135 - val_y2_output_loss: 8.1900 - val_y1_output_root_mean_squared_error: 1.3919 - val_y2_output_root_mean_squared_error: 2.8944
# Epoch 51/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.7640 - y1_output_loss: 1.9344 - y2_output_loss: 3.8770 - y1_output_root_mean_squared_error: 1.3679 - y2_output_root_mean_squared_error: 1.9731 - val_loss: 22.3136 - val_y1_output_loss: 7.0462 - val_y2_output_loss: 14.9262 - val_y1_output_root_mean_squared_error: 2.6293 - val_y2_output_root_mean_squared_error: 3.9243
# Epoch 52/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.7383 - y1_output_loss: 2.8262 - y2_output_loss: 5.8694 - y1_output_root_mean_squared_error: 1.6813 - y2_output_root_mean_squared_error: 2.4314 - val_loss: 7.6453 - val_y1_output_loss: 2.2609 - val_y2_output_loss: 5.5593 - val_y1_output_root_mean_squared_error: 1.5232 - val_y2_output_root_mean_squared_error: 2.3076
# Epoch 53/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.8192 - y1_output_loss: 1.9947 - y2_output_loss: 3.8578 - y1_output_root_mean_squared_error: 1.4024 - y2_output_root_mean_squared_error: 1.9627 - val_loss: 18.5789 - val_y1_output_loss: 3.4897 - val_y2_output_loss: 14.7936 - val_y1_output_root_mean_squared_error: 1.8366 - val_y2_output_root_mean_squared_error: 3.8995
# Epoch 54/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.3757 - y1_output_loss: 1.7979 - y2_output_loss: 4.5478 - y1_output_root_mean_squared_error: 1.3471 - y2_output_root_mean_squared_error: 2.1357 - val_loss: 10.1245 - val_y1_output_loss: 2.3437 - val_y2_output_loss: 7.5654 - val_y1_output_root_mean_squared_error: 1.5418 - val_y2_output_root_mean_squared_error: 2.7834
# Epoch 55/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.1212 - y1_output_loss: 1.8450 - y2_output_loss: 4.3725 - y1_output_root_mean_squared_error: 1.3569 - y2_output_root_mean_squared_error: 2.0688 - val_loss: 14.0750 - val_y1_output_loss: 3.3565 - val_y2_output_loss: 11.2718 - val_y1_output_root_mean_squared_error: 1.8589 - val_y2_output_root_mean_squared_error: 3.2588
# Epoch 56/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.7316 - y1_output_loss: 2.4560 - y2_output_loss: 5.2436 - y1_output_root_mean_squared_error: 1.5671 - y2_output_root_mean_squared_error: 2.2969 - val_loss: 13.1762 - val_y1_output_loss: 3.7785 - val_y2_output_loss: 9.2834 - val_y1_output_root_mean_squared_error: 1.9004 - val_y2_output_root_mean_squared_error: 3.0927
# Epoch 57/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.6916 - y1_output_loss: 1.8050 - y2_output_loss: 3.8599 - y1_output_root_mean_squared_error: 1.3431 - y2_output_root_mean_squared_error: 1.9717 - val_loss: 6.5748 - val_y1_output_loss: 1.7861 - val_y2_output_loss: 4.8147 - val_y1_output_root_mean_squared_error: 1.3183 - val_y2_output_root_mean_squared_error: 2.1993
# Epoch 58/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.0204 - y1_output_loss: 1.8532 - y2_output_loss: 4.1177 - y1_output_root_mean_squared_error: 1.3657 - y2_output_root_mean_squared_error: 2.0385 - val_loss: 6.2153 - val_y1_output_loss: 1.6237 - val_y2_output_loss: 4.7088 - val_y1_output_root_mean_squared_error: 1.2901 - val_y2_output_root_mean_squared_error: 2.1333
# Epoch 59/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.4768 - y1_output_loss: 1.6564 - y2_output_loss: 3.8310 - y1_output_root_mean_squared_error: 1.2902 - y2_output_root_mean_squared_error: 1.9525 - val_loss: 6.4203 - val_y1_output_loss: 1.7248 - val_y2_output_loss: 4.6224 - val_y1_output_root_mean_squared_error: 1.3358 - val_y2_output_root_mean_squared_error: 2.1531
# Epoch 60/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.0935 - y1_output_loss: 2.0527 - y2_output_loss: 5.0101 - y1_output_root_mean_squared_error: 1.4360 - y2_output_root_mean_squared_error: 2.2431 - val_loss: 14.5184 - val_y1_output_loss: 2.4389 - val_y2_output_loss: 11.7602 - val_y1_output_root_mean_squared_error: 1.5395 - val_y2_output_root_mean_squared_error: 3.4855
# Epoch 61/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.0010 - y1_output_loss: 1.7647 - y2_output_loss: 4.1953 - y1_output_root_mean_squared_error: 1.3308 - y2_output_root_mean_squared_error: 2.0567 - val_loss: 23.7335 - val_y1_output_loss: 7.6034 - val_y2_output_loss: 15.5476 - val_y1_output_root_mean_squared_error: 2.7730 - val_y2_output_root_mean_squared_error: 4.0055
# Epoch 62/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.5869 - y1_output_loss: 1.8096 - y2_output_loss: 3.9779 - y1_output_root_mean_squared_error: 1.3396 - y2_output_root_mean_squared_error: 1.9474 - val_loss: 21.5592 - val_y1_output_loss: 3.4240 - val_y2_output_loss: 19.5819 - val_y1_output_root_mean_squared_error: 1.8590 - val_y2_output_root_mean_squared_error: 4.2548
# Epoch 63/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.0646 - y1_output_loss: 1.7432 - y2_output_loss: 4.2653 - y1_output_root_mean_squared_error: 1.3260 - y2_output_root_mean_squared_error: 2.0752 - val_loss: 6.0846 - val_y1_output_loss: 1.2119 - val_y2_output_loss: 4.8296 - val_y1_output_root_mean_squared_error: 1.0998 - val_y2_output_root_mean_squared_error: 2.2079
# Epoch 64/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.5365 - y1_output_loss: 1.6655 - y2_output_loss: 4.8525 - y1_output_root_mean_squared_error: 1.2897 - y2_output_root_mean_squared_error: 2.2075 - val_loss: 6.8131 - val_y1_output_loss: 2.0561 - val_y2_output_loss: 4.7993 - val_y1_output_root_mean_squared_error: 1.4220 - val_y2_output_root_mean_squared_error: 2.1888
# Epoch 65/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.7655 - y1_output_loss: 1.3129 - y2_output_loss: 3.4256 - y1_output_root_mean_squared_error: 1.1437 - y2_output_root_mean_squared_error: 1.8594 - val_loss: 5.5588 - val_y1_output_loss: 1.2539 - val_y2_output_loss: 4.3948 - val_y1_output_root_mean_squared_error: 1.1315 - val_y2_output_root_mean_squared_error: 2.0685
# Epoch 66/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.5299 - y1_output_loss: 1.2607 - y2_output_loss: 3.2607 - y1_output_root_mean_squared_error: 1.1254 - y2_output_root_mean_squared_error: 1.8065 - val_loss: 6.1520 - val_y1_output_loss: 1.0080 - val_y2_output_loss: 5.6926 - val_y1_output_root_mean_squared_error: 1.0158 - val_y2_output_root_mean_squared_error: 2.2628
# Epoch 67/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.6361 - y1_output_loss: 2.1337 - y2_output_loss: 5.4479 - y1_output_root_mean_squared_error: 1.4633 - y2_output_root_mean_squared_error: 2.3441 - val_loss: 5.6870 - val_y1_output_loss: 1.4886 - val_y2_output_loss: 4.2249 - val_y1_output_root_mean_squared_error: 1.2409 - val_y2_output_root_mean_squared_error: 2.0364
# Epoch 68/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.2888 - y1_output_loss: 1.4130 - y2_output_loss: 3.9083 - y1_output_root_mean_squared_error: 1.1808 - y2_output_root_mean_squared_error: 1.9734 - val_loss: 5.6605 - val_y1_output_loss: 1.1780 - val_y2_output_loss: 4.7357 - val_y1_output_root_mean_squared_error: 1.1025 - val_y2_output_root_mean_squared_error: 2.1083
# Epoch 69/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.8307 - y1_output_loss: 1.1844 - y2_output_loss: 3.6123 - y1_output_root_mean_squared_error: 1.0901 - y2_output_root_mean_squared_error: 1.9085 - val_loss: 5.6685 - val_y1_output_loss: 1.3161 - val_y2_output_loss: 4.3385 - val_y1_output_root_mean_squared_error: 1.1485 - val_y2_output_root_mean_squared_error: 2.0855
# Epoch 70/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.0952 - y1_output_loss: 1.5170 - y2_output_loss: 3.5488 - y1_output_root_mean_squared_error: 1.2346 - y2_output_root_mean_squared_error: 1.8897 - val_loss: 5.6915 - val_y1_output_loss: 1.2492 - val_y2_output_loss: 4.5388 - val_y1_output_root_mean_squared_error: 1.1218 - val_y2_output_root_mean_squared_error: 2.1055
# Epoch 71/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.1810 - y1_output_loss: 1.0567 - y2_output_loss: 3.1326 - y1_output_root_mean_squared_error: 1.0286 - y2_output_root_mean_squared_error: 1.7672 - val_loss: 11.9380 - val_y1_output_loss: 3.0895 - val_y2_output_loss: 8.5944 - val_y1_output_root_mean_squared_error: 1.7472 - val_y2_output_root_mean_squared_error: 2.9808
# Epoch 72/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.8455 - y1_output_loss: 1.3683 - y2_output_loss: 3.4468 - y1_output_root_mean_squared_error: 1.1716 - y2_output_root_mean_squared_error: 1.8635 - val_loss: 4.9543 - val_y1_output_loss: 0.9391 - val_y2_output_loss: 3.9798 - val_y1_output_root_mean_squared_error: 0.9749 - val_y2_output_root_mean_squared_error: 2.0010
# Epoch 73/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.8320 - y1_output_loss: 1.2976 - y2_output_loss: 3.5257 - y1_output_root_mean_squared_error: 1.1406 - y2_output_root_mean_squared_error: 1.8791 - val_loss: 7.2177 - val_y1_output_loss: 2.2029 - val_y2_output_loss: 5.3035 - val_y1_output_root_mean_squared_error: 1.4897 - val_y2_output_root_mean_squared_error: 2.2358
# Epoch 74/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.9810 - y1_output_loss: 1.2890 - y2_output_loss: 3.6853 - y1_output_root_mean_squared_error: 1.1392 - y2_output_root_mean_squared_error: 1.9192 - val_loss: 7.8446 - val_y1_output_loss: 0.8811 - val_y2_output_loss: 7.6081 - val_y1_output_root_mean_squared_error: 0.9547 - val_y2_output_root_mean_squared_error: 2.6331
# Epoch 75/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.9872 - y1_output_loss: 1.0442 - y2_output_loss: 2.9298 - y1_output_root_mean_squared_error: 1.0235 - y2_output_root_mean_squared_error: 1.7145 - val_loss: 5.7258 - val_y1_output_loss: 1.1306 - val_y2_output_loss: 4.5334 - val_y1_output_root_mean_squared_error: 1.0614 - val_y2_output_root_mean_squared_error: 2.1446
# Epoch 76/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.7139 - y1_output_loss: 1.3066 - y2_output_loss: 3.3841 - y1_output_root_mean_squared_error: 1.1456 - y2_output_root_mean_squared_error: 1.8443 - val_loss: 5.4191 - val_y1_output_loss: 1.0182 - val_y2_output_loss: 4.7545 - val_y1_output_root_mean_squared_error: 1.0169 - val_y2_output_root_mean_squared_error: 2.0940
# Epoch 77/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.0502 - y1_output_loss: 1.1365 - y2_output_loss: 2.9897 - y1_output_root_mean_squared_error: 1.0376 - y2_output_root_mean_squared_error: 1.7244 - val_loss: 27.8058 - val_y1_output_loss: 9.3356 - val_y2_output_loss: 19.3172 - val_y1_output_root_mean_squared_error: 3.0849 - val_y2_output_root_mean_squared_error: 4.2766
# Epoch 78/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.7121 - y1_output_loss: 1.1471 - y2_output_loss: 3.6008 - y1_output_root_mean_squared_error: 1.0750 - y2_output_root_mean_squared_error: 1.8859 - val_loss: 17.2316 - val_y1_output_loss: 2.8098 - val_y2_output_loss: 15.5716 - val_y1_output_root_mean_squared_error: 1.6936 - val_y2_output_root_mean_squared_error: 3.7899
# Epoch 79/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.5974 - y1_output_loss: 1.4945 - y2_output_loss: 4.0888 - y1_output_root_mean_squared_error: 1.2255 - y2_output_root_mean_squared_error: 2.0237 - val_loss: 5.3167 - val_y1_output_loss: 1.1471 - val_y2_output_loss: 4.1666 - val_y1_output_root_mean_squared_error: 1.0536 - val_y2_output_root_mean_squared_error: 2.0510
# Epoch 80/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.5472 - y1_output_loss: 0.8506 - y2_output_loss: 2.7182 - y1_output_root_mean_squared_error: 0.9177 - y2_output_root_mean_squared_error: 1.6447 - val_loss: 5.7699 - val_y1_output_loss: 1.3900 - val_y2_output_loss: 4.6697 - val_y1_output_root_mean_squared_error: 1.2007 - val_y2_output_root_mean_squared_error: 2.0804
# Epoch 81/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.0398 - y1_output_loss: 0.9296 - y2_output_loss: 3.0893 - y1_output_root_mean_squared_error: 0.9618 - y2_output_root_mean_squared_error: 1.7649 - val_loss: 4.1666 - val_y1_output_loss: 0.5859 - val_y2_output_loss: 3.9717 - val_y1_output_root_mean_squared_error: 0.7776 - val_y2_output_root_mean_squared_error: 1.8873
# Epoch 82/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.3404 - y1_output_loss: 0.7174 - y2_output_loss: 2.6085 - y1_output_root_mean_squared_error: 0.8485 - y2_output_root_mean_squared_error: 1.6188 - val_loss: 6.2803 - val_y1_output_loss: 0.6779 - val_y2_output_loss: 5.5194 - val_y1_output_root_mean_squared_error: 0.8298 - val_y2_output_root_mean_squared_error: 2.3647
# Epoch 83/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.4891 - y1_output_loss: 1.1755 - y2_output_loss: 3.3562 - y1_output_root_mean_squared_error: 1.0861 - y2_output_root_mean_squared_error: 1.8192 - val_loss: 14.9137 - val_y1_output_loss: 2.1498 - val_y2_output_loss: 12.4504 - val_y1_output_root_mean_squared_error: 1.4381 - val_y2_output_root_mean_squared_error: 3.5841
# Epoch 84/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.6142 - y1_output_loss: 1.2424 - y2_output_loss: 3.3503 - y1_output_root_mean_squared_error: 1.1180 - y2_output_root_mean_squared_error: 1.8342 - val_loss: 6.2781 - val_y1_output_loss: 1.4287 - val_y2_output_loss: 4.8195 - val_y1_output_root_mean_squared_error: 1.1899 - val_y2_output_root_mean_squared_error: 2.2051
# Epoch 85/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.8516 - y1_output_loss: 1.1753 - y2_output_loss: 3.6563 - y1_output_root_mean_squared_error: 1.0835 - y2_output_root_mean_squared_error: 1.9177 - val_loss: 5.2744 - val_y1_output_loss: 1.2194 - val_y2_output_loss: 4.3729 - val_y1_output_root_mean_squared_error: 1.1222 - val_y2_output_root_mean_squared_error: 2.0038
# Epoch 86/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.5669 - y1_output_loss: 1.0371 - y2_output_loss: 3.4889 - y1_output_root_mean_squared_error: 1.0224 - y2_output_root_mean_squared_error: 1.8766 - val_loss: 3.6978 - val_y1_output_loss: 0.5033 - val_y2_output_loss: 3.4656 - val_y1_output_root_mean_squared_error: 0.7101 - val_y2_output_root_mean_squared_error: 1.7870
# Epoch 87/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.1961 - y1_output_loss: 0.7768 - y2_output_loss: 2.5457 - y1_output_root_mean_squared_error: 0.8705 - y2_output_root_mean_squared_error: 1.5615 - val_loss: 11.1066 - val_y1_output_loss: 4.0343 - val_y2_output_loss: 7.0871 - val_y1_output_root_mean_squared_error: 1.9686 - val_y2_output_root_mean_squared_error: 2.6891
# Epoch 88/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.4499 - y1_output_loss: 0.8711 - y2_output_loss: 2.6358 - y1_output_root_mean_squared_error: 0.9372 - y2_output_root_mean_squared_error: 1.6036 - val_loss: 10.8409 - val_y1_output_loss: 1.3438 - val_y2_output_loss: 10.5975 - val_y1_output_root_mean_squared_error: 1.1699 - val_y2_output_root_mean_squared_error: 3.0777
# Epoch 89/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.3856 - y1_output_loss: 0.6944 - y2_output_loss: 2.6776 - y1_output_root_mean_squared_error: 0.8358 - y2_output_root_mean_squared_error: 1.6392 - val_loss: 5.2705 - val_y1_output_loss: 1.1277 - val_y2_output_loss: 4.5160 - val_y1_output_root_mean_squared_error: 1.0769 - val_y2_output_root_mean_squared_error: 2.0275
# Epoch 90/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.1897 - y1_output_loss: 0.9560 - y2_output_loss: 3.2078 - y1_output_root_mean_squared_error: 0.9774 - y2_output_root_mean_squared_error: 1.7984 - val_loss: 3.4801 - val_y1_output_loss: 0.5257 - val_y2_output_loss: 3.1895 - val_y1_output_root_mean_squared_error: 0.7205 - val_y2_output_root_mean_squared_error: 1.7208
# Epoch 91/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.2283 - y1_output_loss: 1.0288 - y2_output_loss: 3.1651 - y1_output_root_mean_squared_error: 1.0167 - y2_output_root_mean_squared_error: 1.7873 - val_loss: 4.4422 - val_y1_output_loss: 0.7948 - val_y2_output_loss: 3.8323 - val_y1_output_root_mean_squared_error: 0.9039 - val_y2_output_root_mean_squared_error: 1.9040
# Epoch 92/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.1785 - y1_output_loss: 0.7356 - y2_output_loss: 2.4575 - y1_output_root_mean_squared_error: 0.8612 - y2_output_root_mean_squared_error: 1.5610 - val_loss: 4.4994 - val_y1_output_loss: 0.8835 - val_y2_output_loss: 4.0078 - val_y1_output_root_mean_squared_error: 0.9511 - val_y2_output_root_mean_squared_error: 1.8960
# Epoch 93/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.2598 - y1_output_loss: 1.4621 - y2_output_loss: 3.7621 - y1_output_root_mean_squared_error: 1.2142 - y2_output_root_mean_squared_error: 1.9456 - val_loss: 3.7410 - val_y1_output_loss: 0.5676 - val_y2_output_loss: 3.4862 - val_y1_output_root_mean_squared_error: 0.7638 - val_y2_output_root_mean_squared_error: 1.7770
# Epoch 94/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.4895 - y1_output_loss: 0.8516 - y2_output_loss: 2.6080 - y1_output_root_mean_squared_error: 0.9259 - y2_output_root_mean_squared_error: 1.6224 - val_loss: 3.7988 - val_y1_output_loss: 0.4854 - val_y2_output_loss: 3.4491 - val_y1_output_root_mean_squared_error: 0.7012 - val_y2_output_root_mean_squared_error: 1.8186
# Epoch 95/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.1988 - y1_output_loss: 1.8007 - y2_output_loss: 4.3677 - y1_output_root_mean_squared_error: 1.3479 - y2_output_root_mean_squared_error: 2.0933 - val_loss: 5.8831 - val_y1_output_loss: 1.2628 - val_y2_output_loss: 4.5613 - val_y1_output_root_mean_squared_error: 1.1301 - val_y2_output_root_mean_squared_error: 2.1461
# Epoch 96/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.3598 - y1_output_loss: 1.0612 - y2_output_loss: 3.3028 - y1_output_root_mean_squared_error: 1.0343 - y2_output_root_mean_squared_error: 1.8139 - val_loss: 8.0567 - val_y1_output_loss: 1.4539 - val_y2_output_loss: 7.4139 - val_y1_output_root_mean_squared_error: 1.2164 - val_y2_output_root_mean_squared_error: 2.5646
# Epoch 97/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.2151 - y1_output_loss: 0.8161 - y2_output_loss: 2.3692 - y1_output_root_mean_squared_error: 0.9076 - y2_output_root_mean_squared_error: 1.5464 - val_loss: 3.3592 - val_y1_output_loss: 0.3946 - val_y2_output_loss: 3.1433 - val_y1_output_root_mean_squared_error: 0.6317 - val_y2_output_root_mean_squared_error: 1.7205
# Epoch 98/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.7570 - y1_output_loss: 0.6013 - y2_output_loss: 2.1317 - y1_output_root_mean_squared_error: 0.7788 - y2_output_root_mean_squared_error: 1.4664 - val_loss: 3.2299 - val_y1_output_loss: 0.4196 - val_y2_output_loss: 3.0982 - val_y1_output_root_mean_squared_error: 0.6515 - val_y2_output_root_mean_squared_error: 1.6749
# Epoch 99/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.1908 - y1_output_loss: 0.7877 - y2_output_loss: 2.3855 - y1_output_root_mean_squared_error: 0.8918 - y2_output_root_mean_squared_error: 1.5477 - val_loss: 3.7599 - val_y1_output_loss: 0.6409 - val_y2_output_loss: 3.2560 - val_y1_output_root_mean_squared_error: 0.7943 - val_y2_output_root_mean_squared_error: 1.7689
# Epoch 100/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.0728 - y1_output_loss: 1.1808 - y2_output_loss: 3.8782 - y1_output_root_mean_squared_error: 1.0780 - y2_output_root_mean_squared_error: 1.9775 - val_loss: 5.6592 - val_y1_output_loss: 1.4682 - val_y2_output_loss: 4.5742 - val_y1_output_root_mean_squared_error: 1.2311 - val_y2_output_root_mean_squared_error: 2.0356
# Epoch 101/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.2627 - y1_output_loss: 0.7256 - y2_output_loss: 2.6104 - y1_output_root_mean_squared_error: 0.8457 - y2_output_root_mean_squared_error: 1.5961 - val_loss: 16.0702 - val_y1_output_loss: 1.8861 - val_y2_output_loss: 13.8476 - val_y1_output_root_mean_squared_error: 1.3487 - val_y2_output_root_mean_squared_error: 3.7751
# Epoch 102/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.5824 - y1_output_loss: 0.7281 - y2_output_loss: 2.8301 - y1_output_root_mean_squared_error: 0.8569 - y2_output_root_mean_squared_error: 1.6876 - val_loss: 3.5445 - val_y1_output_loss: 0.5443 - val_y2_output_loss: 3.2097 - val_y1_output_root_mean_squared_error: 0.7456 - val_y2_output_root_mean_squared_error: 1.7287
# Epoch 103/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.4003 - y1_output_loss: 0.5032 - y2_output_loss: 1.8867 - y1_output_root_mean_squared_error: 0.7128 - y2_output_root_mean_squared_error: 1.3756 - val_loss: 3.0644 - val_y1_output_loss: 0.4558 - val_y2_output_loss: 2.8805 - val_y1_output_root_mean_squared_error: 0.6803 - val_y2_output_root_mean_squared_error: 1.6130
# Epoch 104/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.5635 - y1_output_loss: 0.6181 - y2_output_loss: 1.9525 - y1_output_root_mean_squared_error: 0.7874 - y2_output_root_mean_squared_error: 1.3941 - val_loss: 8.8649 - val_y1_output_loss: 1.1859 - val_y2_output_loss: 7.4272 - val_y1_output_root_mean_squared_error: 1.0924 - val_y2_output_root_mean_squared_error: 2.7698
# Epoch 105/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.9612 - y1_output_loss: 0.9636 - y2_output_loss: 3.0116 - y1_output_root_mean_squared_error: 0.9861 - y2_output_root_mean_squared_error: 1.7288 - val_loss: 6.1345 - val_y1_output_loss: 1.1772 - val_y2_output_loss: 5.6914 - val_y1_output_root_mean_squared_error: 1.0873 - val_y2_output_root_mean_squared_error: 2.2254
# Epoch 106/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.7082 - y1_output_loss: 0.6440 - y2_output_loss: 2.0761 - y1_output_root_mean_squared_error: 0.8021 - y2_output_root_mean_squared_error: 1.4370 - val_loss: 6.3235 - val_y1_output_loss: 1.5386 - val_y2_output_loss: 4.7704 - val_y1_output_root_mean_squared_error: 1.2318 - val_y2_output_root_mean_squared_error: 2.1923
# Epoch 107/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.4611 - y1_output_loss: 0.5679 - y2_output_loss: 1.8980 - y1_output_root_mean_squared_error: 0.7478 - y2_output_root_mean_squared_error: 1.3791 - val_loss: 11.3926 - val_y1_output_loss: 3.1796 - val_y2_output_loss: 7.9796 - val_y1_output_root_mean_squared_error: 1.7821 - val_y2_output_root_mean_squared_error: 2.8665
# Epoch 108/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.4379 - y1_output_loss: 0.5921 - y2_output_loss: 1.8243 - y1_output_root_mean_squared_error: 0.7723 - y2_output_root_mean_squared_error: 1.3570 - val_loss: 3.2346 - val_y1_output_loss: 0.4904 - val_y2_output_loss: 3.1141 - val_y1_output_root_mean_squared_error: 0.7116 - val_y2_output_root_mean_squared_error: 1.6518
# Epoch 109/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.6693 - y1_output_loss: 0.5997 - y2_output_loss: 2.0668 - y1_output_root_mean_squared_error: 0.7754 - y2_output_root_mean_squared_error: 1.4381 - val_loss: 3.7428 - val_y1_output_loss: 0.7407 - val_y2_output_loss: 3.1832 - val_y1_output_root_mean_squared_error: 0.8635 - val_y2_output_root_mean_squared_error: 1.7312
# Epoch 110/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.7333 - y1_output_loss: 0.6017 - y2_output_loss: 2.1277 - y1_output_root_mean_squared_error: 0.7694 - y2_output_root_mean_squared_error: 1.4633 - val_loss: 5.6017 - val_y1_output_loss: 1.5117 - val_y2_output_loss: 4.5533 - val_y1_output_root_mean_squared_error: 1.2469 - val_y2_output_root_mean_squared_error: 2.0117
# Epoch 111/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.8676 - y1_output_loss: 0.6643 - y2_output_loss: 2.2446 - y1_output_root_mean_squared_error: 0.8136 - y2_output_root_mean_squared_error: 1.4852 - val_loss: 14.6987 - val_y1_output_loss: 1.9284 - val_y2_output_loss: 12.3392 - val_y1_output_root_mean_squared_error: 1.3811 - val_y2_output_root_mean_squared_error: 3.5765
# Epoch 112/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.5470 - y1_output_loss: 0.6048 - y2_output_loss: 1.9348 - y1_output_root_mean_squared_error: 0.7807 - y2_output_root_mean_squared_error: 1.3919 - val_loss: 4.4024 - val_y1_output_loss: 0.5324 - val_y2_output_loss: 4.4458 - val_y1_output_root_mean_squared_error: 0.7401 - val_y2_output_root_mean_squared_error: 1.9633
# Epoch 113/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1608 - y1_output_loss: 0.6742 - y2_output_loss: 2.4808 - y1_output_root_mean_squared_error: 0.8223 - y2_output_root_mean_squared_error: 1.5763 - val_loss: 3.5767 - val_y1_output_loss: 0.7206 - val_y2_output_loss: 3.0806 - val_y1_output_root_mean_squared_error: 0.8439 - val_y2_output_root_mean_squared_error: 1.6925
# Epoch 114/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.0295 - y1_output_loss: 0.7075 - y2_output_loss: 2.3204 - y1_output_root_mean_squared_error: 0.8408 - y2_output_root_mean_squared_error: 1.5240 - val_loss: 4.7348 - val_y1_output_loss: 0.9547 - val_y2_output_loss: 4.2217 - val_y1_output_root_mean_squared_error: 0.9918 - val_y2_output_root_mean_squared_error: 1.9368
# Epoch 115/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.9317 - y1_output_loss: 0.6576 - y2_output_loss: 2.2579 - y1_output_root_mean_squared_error: 0.8113 - y2_output_root_mean_squared_error: 1.5078 - val_loss: 3.4382 - val_y1_output_loss: 0.4580 - val_y2_output_loss: 3.4736 - val_y1_output_root_mean_squared_error: 0.6844 - val_y2_output_root_mean_squared_error: 1.7233
# Epoch 116/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.2408 - y1_output_loss: 0.4900 - y2_output_loss: 1.7679 - y1_output_root_mean_squared_error: 0.6983 - y2_output_root_mean_squared_error: 1.3241 - val_loss: 4.7909 - val_y1_output_loss: 0.6744 - val_y2_output_loss: 4.0835 - val_y1_output_root_mean_squared_error: 0.8057 - val_y2_output_root_mean_squared_error: 2.0351
# Epoch 117/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.3196 - y1_output_loss: 0.7013 - y2_output_loss: 2.6118 - y1_output_root_mean_squared_error: 0.8363 - y2_output_root_mean_squared_error: 1.6187 - val_loss: 5.6446 - val_y1_output_loss: 1.1560 - val_y2_output_loss: 4.4578 - val_y1_output_root_mean_squared_error: 1.0586 - val_y2_output_root_mean_squared_error: 2.1269
# Epoch 118/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.6632 - y1_output_loss: 0.5986 - y2_output_loss: 2.0576 - y1_output_root_mean_squared_error: 0.7768 - y2_output_root_mean_squared_error: 1.4352 - val_loss: 3.2049 - val_y1_output_loss: 0.4318 - val_y2_output_loss: 3.1731 - val_y1_output_root_mean_squared_error: 0.6656 - val_y2_output_root_mean_squared_error: 1.6619
# Epoch 119/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.9513 - y1_output_loss: 0.5839 - y2_output_loss: 2.3407 - y1_output_root_mean_squared_error: 0.7675 - y2_output_root_mean_squared_error: 1.5369 - val_loss: 3.0151 - val_y1_output_loss: 0.5026 - val_y2_output_loss: 2.8684 - val_y1_output_root_mean_squared_error: 0.7140 - val_y2_output_root_mean_squared_error: 1.5828
# Epoch 120/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.3420 - y1_output_loss: 0.5419 - y2_output_loss: 1.7958 - y1_output_root_mean_squared_error: 0.7376 - y2_output_root_mean_squared_error: 1.3409 - val_loss: 4.3282 - val_y1_output_loss: 0.4362 - val_y2_output_loss: 3.9802 - val_y1_output_root_mean_squared_error: 0.6585 - val_y2_output_root_mean_squared_error: 1.9735
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.6374 - y1_output_loss: 0.1653 - y2_output_loss: 0.4715 - y1_output_root_mean_squared_error: 0.4078 - y2_output_root_mean_squared_error: 0.6864 - val_loss: 1.5354 - val_y1_output_loss: 0.2029 - val_y2_output_loss: 1.5780 - val_y1_output_root_mean_squared_error: 0.4551 - val_y2_output_root_mean_squared_error: 1.1525
# Epoch 462/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.5154 - y1_output_loss: 0.1342 - y2_output_loss: 0.3815 - y1_output_root_mean_squared_error: 0.3661 - y2_output_root_mean_squared_error: 0.6175 - val_loss: 1.7070 - val_y1_output_loss: 0.2054 - val_y2_output_loss: 1.6546 - val_y1_output_root_mean_squared_error: 0.4549 - val_y2_output_root_mean_squared_error: 1.2248
# Epoch 463/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4102 - y1_output_loss: 0.1163 - y2_output_loss: 0.2972 - y1_output_root_mean_squared_error: 0.3418 - y2_output_root_mean_squared_error: 0.5417 - val_loss: 1.4724 - val_y1_output_loss: 0.1636 - val_y2_output_loss: 1.4165 - val_y1_output_root_mean_squared_error: 0.4054 - val_y2_output_root_mean_squared_error: 1.1437
# Epoch 464/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.4651 - y1_output_loss: 0.1188 - y2_output_loss: 0.3421 - y1_output_root_mean_squared_error: 0.3460 - y2_output_root_mean_squared_error: 0.5877 - val_loss: 1.1953 - val_y1_output_loss: 0.1776 - val_y2_output_loss: 1.2069 - val_y1_output_root_mean_squared_error: 0.4281 - val_y2_output_root_mean_squared_error: 1.0060
# Epoch 465/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4738 - y1_output_loss: 0.1234 - y2_output_loss: 0.3475 - y1_output_root_mean_squared_error: 0.3512 - y2_output_root_mean_squared_error: 0.5920 - val_loss: 1.2154 - val_y1_output_loss: 0.1865 - val_y2_output_loss: 1.2260 - val_y1_output_root_mean_squared_error: 0.4333 - val_y2_output_root_mean_squared_error: 1.0137
# Epoch 466/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4433 - y1_output_loss: 0.1256 - y2_output_loss: 0.3171 - y1_output_root_mean_squared_error: 0.3541 - y2_output_root_mean_squared_error: 0.5638 - val_loss: 1.4823 - val_y1_output_loss: 0.1914 - val_y2_output_loss: 1.6314 - val_y1_output_root_mean_squared_error: 0.4429 - val_y2_output_root_mean_squared_error: 1.1341
# Epoch 467/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.5457 - y1_output_loss: 0.1374 - y2_output_loss: 0.4084 - y1_output_root_mean_squared_error: 0.3705 - y2_output_root_mean_squared_error: 0.6391 - val_loss: 1.3886 - val_y1_output_loss: 0.1810 - val_y2_output_loss: 1.4943 - val_y1_output_root_mean_squared_error: 0.4316 - val_y2_output_root_mean_squared_error: 1.0965
# Epoch 468/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4972 - y1_output_loss: 0.1272 - y2_output_loss: 0.3718 - y1_output_root_mean_squared_error: 0.3583 - y2_output_root_mean_squared_error: 0.6073 - val_loss: 1.1957 - val_y1_output_loss: 0.1692 - val_y2_output_loss: 1.2349 - val_y1_output_root_mean_squared_error: 0.4165 - val_y2_output_root_mean_squared_error: 1.0111
# Epoch 469/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.8796 - y1_output_loss: 0.1786 - y2_output_loss: 0.6980 - y1_output_root_mean_squared_error: 0.4244 - y2_output_root_mean_squared_error: 0.8363 - val_loss: 1.1950 - val_y1_output_loss: 0.1764 - val_y2_output_loss: 1.2407 - val_y1_output_root_mean_squared_error: 0.4236 - val_y2_output_root_mean_squared_error: 1.0077
# Epoch 470/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4792 - y1_output_loss: 0.1281 - y2_output_loss: 0.3766 - y1_output_root_mean_squared_error: 0.3549 - y2_output_root_mean_squared_error: 0.5943 - val_loss: 7.7607 - val_y1_output_loss: 1.3624 - val_y2_output_loss: 6.2222 - val_y1_output_root_mean_squared_error: 1.1712 - val_y2_output_root_mean_squared_error: 2.5276
# Epoch 471/500
# 614/614 [==============================] - 0s 138us/sample - loss: 1.4019 - y1_output_loss: 0.3368 - y2_output_loss: 1.0579 - y1_output_root_mean_squared_error: 0.5830 - y2_output_root_mean_squared_error: 1.0305 - val_loss: 1.3757 - val_y1_output_loss: 0.1799 - val_y2_output_loss: 1.3010 - val_y1_output_root_mean_squared_error: 0.4205 - val_y2_output_root_mean_squared_error: 1.0950
# Epoch 472/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5043 - y1_output_loss: 0.1407 - y2_output_loss: 0.3646 - y1_output_root_mean_squared_error: 0.3743 - y2_output_root_mean_squared_error: 0.6035 - val_loss: 1.1712 - val_y1_output_loss: 0.1525 - val_y2_output_loss: 1.1281 - val_y1_output_root_mean_squared_error: 0.3942 - val_y2_output_root_mean_squared_error: 1.0079
# Epoch 473/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4926 - y1_output_loss: 0.1537 - y2_output_loss: 0.3396 - y1_output_root_mean_squared_error: 0.3935 - y2_output_root_mean_squared_error: 0.5812 - val_loss: 1.7065 - val_y1_output_loss: 0.1742 - val_y2_output_loss: 1.9009 - val_y1_output_root_mean_squared_error: 0.4184 - val_y2_output_root_mean_squared_error: 1.2375
# Epoch 474/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4726 - y1_output_loss: 0.1299 - y2_output_loss: 0.3405 - y1_output_root_mean_squared_error: 0.3604 - y2_output_root_mean_squared_error: 0.5854 - val_loss: 1.0915 - val_y1_output_loss: 0.1848 - val_y2_output_loss: 1.0368 - val_y1_output_root_mean_squared_error: 0.4248 - val_y2_output_root_mean_squared_error: 0.9545
# Epoch 475/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5884 - y1_output_loss: 0.1418 - y2_output_loss: 0.4476 - y1_output_root_mean_squared_error: 0.3750 - y2_output_root_mean_squared_error: 0.6692 - val_loss: 2.0180 - val_y1_output_loss: 0.3225 - val_y2_output_loss: 2.0225 - val_y1_output_root_mean_squared_error: 0.5754 - val_y2_output_root_mean_squared_error: 1.2988
# Epoch 476/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4159 - y1_output_loss: 0.1356 - y2_output_loss: 0.2840 - y1_output_root_mean_squared_error: 0.3689 - y2_output_root_mean_squared_error: 0.5290 - val_loss: 1.1428 - val_y1_output_loss: 0.1886 - val_y2_output_loss: 1.1457 - val_y1_output_root_mean_squared_error: 0.4327 - val_y2_output_root_mean_squared_error: 0.9776
# Epoch 477/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4367 - y1_output_loss: 0.1236 - y2_output_loss: 0.3180 - y1_output_root_mean_squared_error: 0.3453 - y2_output_root_mean_squared_error: 0.5635 - val_loss: 2.5391 - val_y1_output_loss: 0.8685 - val_y2_output_loss: 1.9250 - val_y1_output_root_mean_squared_error: 0.9473 - val_y2_output_root_mean_squared_error: 1.2813
# Epoch 478/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4618 - y1_output_loss: 0.1340 - y2_output_loss: 0.3247 - y1_output_root_mean_squared_error: 0.3671 - y2_output_root_mean_squared_error: 0.5718 - val_loss: 1.1794 - val_y1_output_loss: 0.2131 - val_y2_output_loss: 1.0840 - val_y1_output_root_mean_squared_error: 0.4614 - val_y2_output_root_mean_squared_error: 0.9831
# Epoch 479/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4949 - y1_output_loss: 0.1412 - y2_output_loss: 0.3648 - y1_output_root_mean_squared_error: 0.3682 - y2_output_root_mean_squared_error: 0.5994 - val_loss: 2.4935 - val_y1_output_loss: 1.0467 - val_y2_output_loss: 1.5486 - val_y1_output_root_mean_squared_error: 1.0240 - val_y2_output_root_mean_squared_error: 1.2021
# Epoch 480/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.7867 - y1_output_loss: 0.2032 - y2_output_loss: 0.5778 - y1_output_root_mean_squared_error: 0.4527 - y2_output_root_mean_squared_error: 0.7628 - val_loss: 1.2556 - val_y1_output_loss: 0.1773 - val_y2_output_loss: 1.3155 - val_y1_output_root_mean_squared_error: 0.4276 - val_y2_output_root_mean_squared_error: 1.0357
# Epoch 481/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3969 - y1_output_loss: 0.1210 - y2_output_loss: 0.2816 - y1_output_root_mean_squared_error: 0.3426 - y2_output_root_mean_squared_error: 0.5288 - val_loss: 1.3351 - val_y1_output_loss: 0.2166 - val_y2_output_loss: 1.1932 - val_y1_output_root_mean_squared_error: 0.4629 - val_y2_output_root_mean_squared_error: 1.0587
# Epoch 482/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4151 - y1_output_loss: 0.1330 - y2_output_loss: 0.2871 - y1_output_root_mean_squared_error: 0.3636 - y2_output_root_mean_squared_error: 0.5319 - val_loss: 1.2899 - val_y1_output_loss: 0.1525 - val_y2_output_loss: 1.4196 - val_y1_output_root_mean_squared_error: 0.3947 - val_y2_output_root_mean_squared_error: 1.0650
# Epoch 483/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4429 - y1_output_loss: 0.1367 - y2_output_loss: 0.3056 - y1_output_root_mean_squared_error: 0.3673 - y2_output_root_mean_squared_error: 0.5549 - val_loss: 1.2318 - val_y1_output_loss: 0.2545 - val_y2_output_loss: 1.2138 - val_y1_output_root_mean_squared_error: 0.4996 - val_y2_output_root_mean_squared_error: 0.9911
# Epoch 484/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4284 - y1_output_loss: 0.1243 - y2_output_loss: 0.3128 - y1_output_root_mean_squared_error: 0.3493 - y2_output_root_mean_squared_error: 0.5535 - val_loss: 1.4520 - val_y1_output_loss: 0.2400 - val_y2_output_loss: 1.3687 - val_y1_output_root_mean_squared_error: 0.4965 - val_y2_output_root_mean_squared_error: 1.0979
# Epoch 485/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5020 - y1_output_loss: 0.1441 - y2_output_loss: 0.3541 - y1_output_root_mean_squared_error: 0.3809 - y2_output_root_mean_squared_error: 0.5974 - val_loss: 1.0962 - val_y1_output_loss: 0.1764 - val_y2_output_loss: 1.0536 - val_y1_output_root_mean_squared_error: 0.4175 - val_y2_output_root_mean_squared_error: 0.9602
# Epoch 486/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5180 - y1_output_loss: 0.1317 - y2_output_loss: 0.3871 - y1_output_root_mean_squared_error: 0.3632 - y2_output_root_mean_squared_error: 0.6213 - val_loss: 1.2837 - val_y1_output_loss: 0.1797 - val_y2_output_loss: 1.3490 - val_y1_output_root_mean_squared_error: 0.4285 - val_y2_output_root_mean_squared_error: 1.0488
# Epoch 487/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4289 - y1_output_loss: 0.1395 - y2_output_loss: 0.2877 - y1_output_root_mean_squared_error: 0.3740 - y2_output_root_mean_squared_error: 0.5376 - val_loss: 1.1805 - val_y1_output_loss: 0.2068 - val_y2_output_loss: 1.1584 - val_y1_output_root_mean_squared_error: 0.4622 - val_y2_output_root_mean_squared_error: 0.9833
# Epoch 488/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4445 - y1_output_loss: 0.1319 - y2_output_loss: 0.3249 - y1_output_root_mean_squared_error: 0.3630 - y2_output_root_mean_squared_error: 0.5592 - val_loss: 2.5179 - val_y1_output_loss: 0.1773 - val_y2_output_loss: 2.7367 - val_y1_output_root_mean_squared_error: 0.4278 - val_y2_output_root_mean_squared_error: 1.5280
# Epoch 489/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.6516 - y1_output_loss: 0.1610 - y2_output_loss: 0.4966 - y1_output_root_mean_squared_error: 0.4029 - y2_output_root_mean_squared_error: 0.6995 - val_loss: 1.2880 - val_y1_output_loss: 0.1783 - val_y2_output_loss: 1.2266 - val_y1_output_root_mean_squared_error: 0.4219 - val_y2_output_root_mean_squared_error: 1.0536
# Epoch 490/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5855 - y1_output_loss: 0.1449 - y2_output_loss: 0.4406 - y1_output_root_mean_squared_error: 0.3811 - y2_output_root_mean_squared_error: 0.6635 - val_loss: 1.0205 - val_y1_output_loss: 0.1501 - val_y2_output_loss: 1.0004 - val_y1_output_root_mean_squared_error: 0.3880 - val_y2_output_root_mean_squared_error: 0.9327
# Epoch 491/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3680 - y1_output_loss: 0.1083 - y2_output_loss: 0.2591 - y1_output_root_mean_squared_error: 0.3294 - y2_output_root_mean_squared_error: 0.5094 - val_loss: 1.1101 - val_y1_output_loss: 0.1445 - val_y2_output_loss: 1.0751 - val_y1_output_root_mean_squared_error: 0.3854 - val_y2_output_root_mean_squared_error: 0.9806
# Epoch 492/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4121 - y1_output_loss: 0.1276 - y2_output_loss: 0.2845 - y1_output_root_mean_squared_error: 0.3566 - y2_output_root_mean_squared_error: 0.5338 - val_loss: 1.3240 - val_y1_output_loss: 0.3367 - val_y2_output_loss: 1.1259 - val_y1_output_root_mean_squared_error: 0.5821 - val_y2_output_root_mean_squared_error: 0.9925
# Epoch 493/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4749 - y1_output_loss: 0.1373 - y2_output_loss: 0.3342 - y1_output_root_mean_squared_error: 0.3708 - y2_output_root_mean_squared_error: 0.5808 - val_loss: 1.3055 - val_y1_output_loss: 0.2210 - val_y2_output_loss: 1.3183 - val_y1_output_root_mean_squared_error: 0.4784 - val_y2_output_root_mean_squared_error: 1.0376
# Epoch 494/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4346 - y1_output_loss: 0.1178 - y2_output_loss: 0.3184 - y1_output_root_mean_squared_error: 0.3425 - y2_output_root_mean_squared_error: 0.5633 - val_loss: 1.5532 - val_y1_output_loss: 0.1721 - val_y2_output_loss: 1.6307 - val_y1_output_root_mean_squared_error: 0.4202 - val_y2_output_root_mean_squared_error: 1.1733
# Epoch 495/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4082 - y1_output_loss: 0.1143 - y2_output_loss: 0.2923 - y1_output_root_mean_squared_error: 0.3387 - y2_output_root_mean_squared_error: 0.5417 - val_loss: 1.0775 - val_y1_output_loss: 0.1579 - val_y2_output_loss: 1.1034 - val_y1_output_root_mean_squared_error: 0.4002 - val_y2_output_root_mean_squared_error: 0.9578
# Epoch 496/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4373 - y1_output_loss: 0.1151 - y2_output_loss: 0.3225 - y1_output_root_mean_squared_error: 0.3378 - y2_output_root_mean_squared_error: 0.5685 - val_loss: 1.1143 - val_y1_output_loss: 0.1739 - val_y2_output_loss: 1.1020 - val_y1_output_root_mean_squared_error: 0.4232 - val_y2_output_root_mean_squared_error: 0.9670
# Epoch 497/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4959 - y1_output_loss: 0.1312 - y2_output_loss: 0.3605 - y1_output_root_mean_squared_error: 0.3635 - y2_output_root_mean_squared_error: 0.6031 - val_loss: 1.0698 - val_y1_output_loss: 0.1662 - val_y2_output_loss: 1.0238 - val_y1_output_root_mean_squared_error: 0.4050 - val_y2_output_root_mean_squared_error: 0.9517
# Epoch 498/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4702 - y1_output_loss: 0.1631 - y2_output_loss: 0.3045 - y1_output_root_mean_squared_error: 0.4042 - y2_output_root_mean_squared_error: 0.5539 - val_loss: 1.4114 - val_y1_output_loss: 0.3773 - val_y2_output_loss: 1.1890 - val_y1_output_root_mean_squared_error: 0.6128 - val_y2_output_root_mean_squared_error: 1.0178
# Epoch 499/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5337 - y1_output_loss: 0.1389 - y2_output_loss: 0.3914 - y1_output_root_mean_squared_error: 0.3738 - y2_output_root_mean_squared_error: 0.6277 - val_loss: 1.1267 - val_y1_output_loss: 0.1746 - val_y2_output_loss: 1.1652 - val_y1_output_root_mean_squared_error: 0.4211 - val_y2_output_root_mean_squared_error: 0.9743
# Epoch 500/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4271 - y1_output_loss: 0.1287 - y2_output_loss: 0.2998 - y1_output_root_mean_squared_error: 0.3598 - y2_output_root_mean_squared_error: 0.5455 - val_loss: 1.3513 - val_y1_output_loss: 0.1412 - val_y2_output_loss: 1.2731 - val_y1_output_root_mean_squared_error: 0.3781 - val_y2_output_root_mean_squared_error: 1.0992

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 33us/sample - loss: 1.3513 - y1_output_loss: 0.1433 - y2_output_loss: 1.2337 - y1_output_root_mean_squared_error: 0.3781 - y2_output_root_mean_squared_error: 1.0992
# Loss = 1.351281519060011, Y1_loss = 0.14327417314052582, Y1_mse = 0.37812891602516174, Y2_loss = 1.233701467514038, Y2_mse = 1.099226951599121

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
